# %% [markdown]
# Generate

# %%
import algorithms as alg

alg.GenerateTrainData("./data/membrane/train/image",
                      "./data/membrane/train/label",
                      "./data/membrane/test",  [1, 5, 6])
# Out:
# Lossy conversion from float64 to uint8. Range [0.0, 8.733333333333333]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.498039215686275]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/1/Ground/liver_GT_00057
# ./CT_data_batch1/1/Ground/liver_GT_002
# e:\Program_Code\3_2\SegmentMedImages\Unet\algorithms.py:46: UserWarning: ./data/membrane/train/label\1.png is a low contrast image
#   io.imsave(os.path.join(save_label_path, "{}.png".format(train_counter)), label)
# Lossy conversion from float64 to uint8. Range [0.0, 8.988235294117647]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.050980392156863]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/1/Ground/liver_GT_008
# ./CT_data_batch1/1/Ground/liver_GT_00073
# Lossy conversion from float64 to uint8. Range [0.0, 9.031372549019608]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.431372549019608]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/1/Ground/liver_GT_00045
# ./CT_data_batch1/1/Ground/liver_GT_00020
# Lossy conversion from float64 to uint8. Range [0.0, 8.976470588235294]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.007843137254902]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/1/Ground/liver_GT_00014
# ./CT_data_batch1/1/Ground/liver_GT_00049
# Lossy conversion from float64 to uint8. Range [0.0, 9.066666666666666]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.580392156862745]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/1/Ground/liver_GT_00051
# ./CT_data_batch1/1/Ground/liver_GT_00079
# ./CT_data_batch1/1/Ground/liver_GT_00030
# Lossy conversion from float64 to uint8. Range [0.07450980392156863, 9.364705882352942]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.325490196078432]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.611764705882353]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.07843137254902]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/1/Ground/liver_GT_00040
# ./CT_data_batch1/1/Ground/liver_GT_00085
# ./CT_data_batch1/1/Ground/liver_GT_00054
# ./CT_data_batch1/1/Ground/liver_GT_00046
# Lossy conversion from float64 to uint8. Range [0.0, 8.51764705882353]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.4]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.694117647058823]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.729411764705882]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/1/Ground/liver_GT_00047
# ./CT_data_batch1/1/Ground/liver_GT_00036
# ./CT_data_batch1/1/Ground/liver_GT_006
# Lossy conversion from float64 to uint8. Range [0.0, 8.847058823529412]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.035294117647059]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/1/Ground/liver_GT_00058
# ./CT_data_batch1/1/Ground/liver_GT_00065
# ./CT_data_batch1/5/Ground/liver_GT_00013
# Lossy conversion from float64 to uint8. Range [0.0, 8.827450980392157]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.050980392156863]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.749019607843136]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/5/Ground/liver_GT_00023
# ./CT_data_batch1/5/Ground/liver_GT_00081
# ./CT_data_batch1/5/Ground/liver_GT_008
# Lossy conversion from float64 to uint8. Range [0.0, 9.098039215686274]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.83921568627451]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.611764705882353]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.576470588235294]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/5/Ground/liver_GT_00051
# ./CT_data_batch1/5/Ground/liver_GT_00041
# ./CT_data_batch1/5/Ground/liver_GT_00055
# Lossy conversion from float64 to uint8. Range [0.0, 8.815686274509805]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.07843137254902]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.95686274509804]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.83529411764706]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/5/Ground/liver_GT_00064
# ./CT_data_batch1/5/Ground/liver_GT_00011
# ./CT_data_batch1/5/Ground/liver_GT_00044
# ./CT_data_batch1/5/Ground/liver_GT_00061
# Lossy conversion from float64 to uint8. Range [0.0, 8.72549019607843]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.980392156862745]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.047058823529412]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.811764705882354]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.992156862745098]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/5/Ground/liver_GT_00025
# ./CT_data_batch1/5/Ground/liver_GT_00070
# ./CT_data_batch1/5/Ground/liver_GT_00077
# ./CT_data_batch1/5/Ground/liver_GT_00052
# ./CT_data_batch1/5/Ground/liver_GT_00072
# ./CT_data_batch1/5/Ground/liver_GT_00068
# Lossy conversion from float64 to uint8. Range [0.0, 8.823529411764707]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.996078431372549]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.658823529411764]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 8.83921568627451]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/5/Ground/liver_GT_00078
# ./CT_data_batch1/5/Ground/liver_GT_00029
# ./CT_data_batch1/5/Ground/liver_GT_00024
# ./CT_data_batch1/6/Ground/liver_GT_001
# Lossy conversion from float64 to uint8. Range [0.0, 9.549019607843137]. Convert image to uint8 prior to saving to suppress this warning.
# e:\Program_Code\3_2\SegmentMedImages\Unet\algorithms.py:46: UserWarning: ./data/membrane/train/label\20.png is a low contrast image
#   io.imsave(os.path.join(save_label_path, "{}.png".format(train_counter)), label)
# Lossy conversion from float64 to uint8. Range [0.0, 9.447058823529412]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_008
# Lossy conversion from float64 to uint8. Range [0.0, 9.701960784313725]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_00050
# ./CT_data_batch1/6/Ground/liver_GT_00012
# Lossy conversion from float64 to uint8. Range [0.0, 9.4]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.63921568627451]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.552941176470588]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_00059
# ./CT_data_batch1/6/Ground/liver_GT_006
# e:\Program_Code\3_2\SegmentMedImages\Unet\algorithms.py:46: UserWarning: ./data/membrane/train/label\25.png is a low contrast image
#   io.imsave(os.path.join(save_label_path, "{}.png".format(train_counter)), label)
# Lossy conversion from float64 to uint8. Range [0.0, 9.4]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.729411764705882]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_00015
# ./CT_data_batch1/6/Ground/liver_GT_00067
# Lossy conversion from float64 to uint8. Range [0.0, 9.619607843137254]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.513725490196078]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_00056
# ./CT_data_batch1/6/Ground/liver_GT_00027
# Lossy conversion from float64 to uint8. Range [0.0, 9.811764705882354]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_00076
# ./CT_data_batch1/6/Ground/liver_GT_00044
# Lossy conversion from float64 to uint8. Range [0.0, 9.635294117647058]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.419607843137255]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_00084
# ./CT_data_batch1/6/Ground/liver_GT_00069
# Lossy conversion from float64 to uint8. Range [0.0, 9.815686274509805]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.815686274509805]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.83921568627451]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_00035
# ./CT_data_batch1/6/Ground/liver_GT_00068
# Lossy conversion from float64 to uint8. Range [0.0, 9.650980392156862]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.415686274509804]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_00021
# ./CT_data_batch1/6/Ground/liver_GT_00016
# Lossy conversion from float64 to uint8. Range [0.0, 9.75294117647059]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 9.498039215686275]. Convert image to uint8 prior to saving to suppress this warning.
# ./CT_data_batch1/6/Ground/liver_GT_00057
# ./CT_data_batch1/6/Ground/liver_GT_00055

# %% [markdown]
# Run Learning

# %%
import os
from data import *
from model import *

data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGenerator = trainGenerator(20, "./data/membrane/train",
                        "image", "label", data_gen_args,
                        save_to_dir="./data/membrane/train/aug")
model = unet()
model_checkpoint = ModelCheckpoint("./data/savetest.hdf5", monitor="loss", verbose=1, save_best_only=True)
model.fit(myGenerator, steps_per_epoch=30, epochs=5, callbacks=[model_checkpoint])
# Out:
# Found 30 images belonging to 1 classes.
# Found 30 images belonging to 1 classes.
# Epoch 1/5
# 30/30 [==============================] - ETA: 0s - loss: 0.3360 - accuracy: 0.9113
# Epoch 00001: loss improved from inf to 0.33596, saving model to ./data\savetest.hdf5
# 30/30 [==============================] - 526s 17s/step - loss: 0.3360 - accuracy: 0.9113
# Epoch 2/5
# 30/30 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9110
# Epoch 00002: loss improved from 0.33596 to 0.18373, saving model to ./data\savetest.hdf5
# 30/30 [==============================] - 507s 17s/step - loss: 0.1837 - accuracy: 0.9110
# Epoch 3/5
# 30/30 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9111
# Epoch 00003: loss improved from 0.18373 to 0.16133, saving model to ./data\savetest.hdf5
# 30/30 [==============================] - 513s 17s/step - loss: 0.1613 - accuracy: 0.9111
# Epoch 4/5
#  7/30 [======>.......................] - ETA: 6:30 - loss: 0.1584 - accuracy: 0.9109
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# e:\Program_Code\3_2\SegmentMedImages\Unet\main.ipynb Cell 3' in <module>
#      <a href='vscode-notebook-cell:/e%3A/Program_Code/3_2/SegmentMedImages/Unet/main.ipynb#ch0000003?line=14'>15</a> model = unet()
#      <a href='vscode-notebook-cell:/e%3A/Program_Code/3_2/SegmentMedImages/Unet/main.ipynb#ch0000003?line=15'>16</a> model_checkpoint = ModelCheckpoint("./data/savetest.hdf5", monitor="loss", verbose=1, save_best_only=True)
# ---> <a href='vscode-notebook-cell:/e%3A/Program_Code/3_2/SegmentMedImages/Unet/main.ipynb#ch0000003?line=16'>17</a> model.fit(myGenerator, steps_per_epoch=30, epochs=5, callbacks=[model_checkpoint])
#
# File c:\Users\Olyni\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/utils/traceback_utils.py?line=61'>62</a> filtered_tb = None
#      <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/utils/traceback_utils.py?line=62'>63</a> try:
# ---> <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/utils/traceback_utils.py?line=63'>64</a>   return fn(*args, **kwargs)
#      <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/utils/traceback_utils.py?line=64'>65</a> except Exception as e:  # pylint: disable=broad-except
#      <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/utils/traceback_utils.py?line=65'>66</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Olyni\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\training.py:1216, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1208'>1209</a> with tf.profiler.experimental.Trace(
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1209'>1210</a>     'train',
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1210'>1211</a>     epoch_num=epoch,
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1211'>1212</a>     step_num=step,
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1212'>1213</a>     batch_size=batch_size,
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1213'>1214</a>     _r=1):
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1214'>1215</a>   callbacks.on_train_batch_begin(step)
# -> <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1215'>1216</a>   tmp_logs = self.train_function(iterator)
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1216'>1217</a>   if data_handler.should_sync:
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/keras/engine/training.py?line=1217'>1218</a>     context.async_wait()
#
# File c:\Users\Olyni\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=147'>148</a> filtered_tb = None
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=148'>149</a> try:
# --> <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=149'>150</a>   return fn(*args, **kwargs)
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Olyni\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\def_function.py:910, in Function.__call__(self, *args, **kwds)
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=906'>907</a> compiler = "xla" if self._jit_compile else "nonXla"
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=908'>909</a> with OptionalXlaContext(self._jit_compile):
# --> <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=909'>910</a>   result = self._call(*args, **kwds)
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=911'>912</a> new_tracing_count = self.experimental_get_tracing_count()
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=912'>913</a> without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Olyni\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\def_function.py:942, in Function._call(self, *args, **kwds)
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=938'>939</a>   self._lock.release()
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=939'>940</a>   # In this case we have created variables on the first call, so we run the
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=940'>941</a>   # defunned version which is guaranteed to never create variables.
# --> <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=941'>942</a>   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=942'>943</a> elif self._stateful_fn is not None:
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=943'>944</a>   # Release the lock early so that multiple threads can perform the call
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=944'>945</a>   # in parallel.
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/def_function.py?line=945'>946</a>   self._lock.release()
#
# File c:\Users\Olyni\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function.__call__(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=3126'>3127</a> with self._lock:
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=3127'>3128</a>   (graph_function,
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=3128'>3129</a>    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=3129'>3130</a> return graph_function._call_flat(
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=3130'>3131</a>     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\Olyni\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py:1959, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1954'>1955</a> possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1955'>1956</a> if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1956'>1957</a>     and executing_eagerly):
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1957'>1958</a>   # No tape is watching; skip to running the function.
# -> <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1958'>1959</a>   return self._build_call_outputs(self._inference_function.call(
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1959'>1960</a>       ctx, args, cancellation_manager=cancellation_manager))
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1960'>1961</a> forward_backward = self._select_forward_and_backward_functions(
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1961'>1962</a>     args,
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1962'>1963</a>     possible_gradient_type,
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1963'>1964</a>     executing_eagerly)
#    <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=1964'>1965</a> forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Olyni\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py:598, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=595'>596</a> with _InterpolateFunctionError(self):
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=596'>597</a>   if cancellation_manager is None:
# --> <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=597'>598</a>     outputs = execute.execute(
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=598'>599</a>         str(self.signature.name),
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=599'>600</a>         num_outputs=self._num_outputs,
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=600'>601</a>         inputs=args,
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=601'>602</a>         attrs=attrs,
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=602'>603</a>         ctx=ctx)
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=603'>604</a>   else:
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=604'>605</a>     outputs = execute.execute_with_cancellation(
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=605'>606</a>         str(self.signature.name),
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=606'>607</a>         num_outputs=self._num_outputs,
#    (...)
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=609'>610</a>         ctx=ctx,
#     <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/function.py?line=610'>611</a>         cancellation_manager=cancellation_manager)
#
# File c:\Users\Olyni\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\execute.py:58, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/execute.py?line=55'>56</a> try:
#      <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/execute.py?line=56'>57</a>   ctx.ensure_initialized()
# ---> <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/execute.py?line=57'>58</a>   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/execute.py?line=58'>59</a>                                       inputs, attrs, num_outputs)
#      <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/execute.py?line=59'>60</a> except core._NotOkStatusException as e:
#      <a href='file:///c%3A/Users/Olyni/AppData/Local/Programs/Python/Python39/lib/site-packages/tensorflow/python/eager/execute.py?line=60'>61</a>   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# Watch Result by Model Prediction

# %%
from data import *
from model import *
model = unet(pretrained_weights="besttry_start.hdf5")
testGene = testGenerator("data/membrane/test")
results = model.predict_generator(testGene, 30, verbose=1)
saveResult("data/membrane/test", results)
# Out:
# C:\Users\Olyni\AppData\Local\Temp\ipykernel_5204\1656854827.py:5: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   results = model.predict_generator(testGene, 30, verbose=1)
# 30/30 [==============================] - 8s 250ms/step
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
import algorithms as alg

loss = [0.3116, 0.2639, 0.2101, 0.1760, 0.1648]
acc = [0.8699, 0.9049, 0.9149, 0.9229, 0.9278]
n_epoch = 5

alg.CreateChartStatisticOfLearning(n_epoch=n_epoch, loss=loss, acc=acc)
# Out:
# [0.   1.25 2.5  3.75 5.  ]

# %%
import algorithms as alg

loss = [0.6922, 0.6870, 0.6830, 0.6790, 0.6750]
acc = [0.9066, 0.9110, 0.9110, 0.9111, 0.9110]
n_epoch = 5

alg.CreateChartStatisticOfLearning(n_epoch=n_epoch, loss=loss, acc=acc)
# Out:
# [0.   1.25 2.5  3.75 5.  ]

# %%
import algorithms as alg

loss = [0.0823, 0.0243, 0.0156, 0.0118, 0.0096]
acc = [0.9663, 0.9902, 0.9936, 0.9951, 0.9960]
n_epoch = 5

alg.CreateChartStatisticOfLearning(n_epoch=n_epoch, loss=loss, acc=acc)
# Out:
# [0.   1.25 2.5  3.75 5.  ]
